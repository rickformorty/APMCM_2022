# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
# pd.set_option('mode.chained_assignment', None)

# %%
high = pd.read_table('C:/Users/Tony/Desktop/high.txt',sep=',',header=None)
high=high[[0,1,2,3]]
high[2]+=11.27
# high[2]=high[2]*(1-high[3])
low = pd.read_table('C:/Users/Tony/Desktop/low.txt',sep=',',header=None)
low=low[[0,1,2,3]]
low[2]+=-0.58
# low[2]=low[2]*(1-low[3])

# %%
ATD=high[2]-low[2]
time=['2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022']
plt.plot(time,ATD)
